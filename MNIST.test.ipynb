# %%
from data_load import *

# %%
x_train, x_test, y_train, y_test = read_lecun_mnist(path = 'C:/Users/maity/OneDrive/Documents/Invariance/MNIST')

# %%
x_train.shape
# Out:
# (10000, 784)

# %%
np.random.seed(1)
envs, test_envs = make_environments(path = 'MNIST', red_0_corrs = [0.2, 0.1])

# %%
plot_images(envs[1][0][envs[1][1]==1])
