# %%
import json
import re
import pandas as pd
pd.set_option('display.max_rows', None)
with open('out5.json', 'r') as f:
    result = f.read()
    
result
res = re.split(r'\n', result)

# %%
res_dict = dict()
for index, string in enumerate(res):
    if string == '':
        continue
    else:
        res_dict[index] = eval(string)
    
df = pd.DataFrame(res_dict).T

# %%
df
# Out:
#    reg_wasserstein reg_var learning_rate         datetime num-steps  \
# 0                5       0         0.001  20200410-203023     12000
# 1                1       0        0.0001  20200410-203023     12000
# 2                4       0         0.001  20200410-203023     12000
# 3               10       0         0.001  20200410-203023     12000
# 4               10       0        0.0001  20200410-203023     12000
# 5                6       0         0.001  20200410-203023     12000
# 6                2       0        0.0001  20200410-203023     12000
# 7                3       0         0.001  20200410-203023     12000
# 8                1       0         0.001  20200410-203024     12000
# 9                2       0         0.001  20200410-203023     12000
# 10               3       0        0.0001  20200410-203023     12000
# 11               9       0         0.001  20200410-203023     12000
# 12               4       0        0.0001  20200410-203023     12000
# 13               7       0         0.001  20200410-203023     12000
# 14               8       0         0.001  20200410-203023     12000
# 15               9       0        0.0001  20200410-203023     12000
# 16               8       0        0.0001  20200410-203023     12000
# 17               7       0        0.0001  20200410-203023     12000
# 18               6       0        0.0001  20200410-203023     12000
# 19               5       0        0.0001  20200410-203023     12000
#
#    wasserstein-epoch sinkhorn-iteration      id  \
# 0                  1                  5  251356
# 1                  1                  5  662101
# 2                  1                  5  244061
# 3                  1                  5  691952
# 4                  1                  5  796462
# 5                  1                  5  971704
# 6                  1                  5  262634
# 7                  1                  5  957137
# 8                  1                  5  980591
# 9                  1                  5  795250
# 10                 1                  5  907300
# 11                 1                  5  551009
# 12                 1                  5  329040
# 13                 1                  5  745006
# 14                 1                  5  109896
# 15                 1                  5  701516
# 16                 1                  5  328129
# 17                 1                  5   50751
# 18                 1                  5  758370
# 19                 1                  5  501150
#
#                                              train  \
# 0   {0: 0.7950000166893005, 1: 0.8980000019073486}
# 1   {0: 0.7925000190734863, 1: 0.8933333158493042}
# 2   {0: 0.8199999928474426, 1: 0.8913333415985107}
# 3   {0: 0.8116666674613953, 1: 0.9113333225250244}
# 4   {0: 0.7858333587646484, 1: 0.8886666893959045}
# 5    {0: 0.815833330154419, 1: 0.8993333578109741}
# 6   {0: 0.7850000262260437, 1: 0.8786666393280029}
# 7   {0: 0.7983333468437195, 1: 0.8973333239555359}
# 8    {0: 0.824999988079071, 1: 0.9073333144187927}
# 9    {0: 0.8133333325386047, 1: 0.909333348274231}
# 10  {0: 0.7683333158493042, 1: 0.8939999938011169}
# 11  {0: 0.7916666865348816, 1: 0.9006666541099548}
# 12  {0: 0.8083333373069763, 1: 0.8913333415985107}
# 13  {0: 0.8208333253860474, 1: 0.8939999938011169}
# 14  {0: 0.8041666746139526, 1: 0.8786666393280029}
# 15   {0: 0.8016666769981384, 1: 0.890666663646698}
# 16  {0: 0.7816666960716248, 1: 0.8953333497047424}
# 17  {0: 0.8149999976158142, 1: 0.8826666474342346}
# 18  {0: 0.8075000047683716, 1: 0.8913333415985107}
# 19  {0: 0.7991666793823242, 1: 0.8980000019073486}
#
#                                                 test
# 0    {0: 0.2070000022649765, 1: 0.38600000739097595}
# 1      {0: 0.5590000152587891, 1: 0.671999990940094}
# 2   {0: 0.19099999964237213, 1: 0.27300000190734863}
# 3   {0: 0.23600000143051147, 1: 0.38499999046325684}
# 4     {0: 0.6190000176429749, 1: 0.7310000061988831}
# 5                 {0: 0.19200000166893005, 1: 0.125}
# 6     {0: 0.22599999606609344, 1: 0.414000004529953}
# 7   {0: 0.23499999940395355, 1: 0.31700000166893005}
# 8      {0: 0.734000027179718, 1: 0.7450000047683716}
# 9    {0: 0.21400000154972076, 1: 0.4490000009536743}
# 10     {0: 0.746999979019165, 1: 0.8679999709129333}
# 11     {0: 0.453000009059906, 1: 0.6179999709129333}
# 12    {0: 0.7440000176429749, 1: 0.8140000104904175}
# 13   {0: 0.2070000022649765, 1: 0.40700000524520874}
# 14  {0: 0.21699999272823334, 1: 0.23199999332427979}
# 15    {0: 0.5709999799728394, 1: 0.6710000038146973}
# 16    {0: 0.7670000195503235, 1: 0.8759999871253967}
# 17   {0: 0.36000001430511475, 1: 0.5759999752044678}
# 18     {0: 0.753000020980835, 1: 0.7760000228881836}
# 19    {0: 0.3370000123977661, 1: 0.5929999947547913}
