# %%
import json
import re

with open('out.json', 'r') as f:
    result = f.read()
    
result
# Out:
# '{"reg_wasserstein": 0.1, "reg_var": 0.01, "learning_rate": 0.01, "datetime": "20200406-215347", "num-steps": 10000, "wasserstein-epoch": 10, "sinkhorn-iteration": 5, "train": {"0": 0.7549999952316284, "1": 0.8159999847412109}, "test": {"0": 0.36399999260902405, "1": 0.5109999775886536}}{"reg_wasserstein": 0.1, "reg_var": 0.1, "learning_rate": 0.0001, "datetime": "20200406-215349", "num-steps": 10000, "wasserstein-epoch": 10, "sinkhorn-iteration": 5, "train": {"0": 0.7325000166893005, "1": 0.7973333597183228}, "test": {"0": 0.41999998688697815, "1": 0.45100000500679016}}{"reg_wasserstein": 10.0, "reg_var": 0.01, "learning_rate": 0.01, "datetime": "20200406-215349", "num-steps": 10000, "wasserstein-epoch": 10, "sinkhorn-iteration": 5, "train": {"0": 0.7358333468437195, "1": 0.7239999771118164}, "test": {"0": 0.3499999940395355, "1": 0.33000001311302185}}{"reg_wasserstein": 10.0, "reg_var": 0.1, "learning_rate": 0.0001, "datetime": "20200406-215357", "num-steps": 10000, "wasserstein-ep
# ...

# %%
res_dict
# Out:
# {}
