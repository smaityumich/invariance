# %%
import tensorflow as tf
from tensorflow.keras import Model, layers
import ot
import numpy as np
from utils import *

# %%
y0 = np.random.binomial(1, 0.5, (1200,))
y1 = np.random.binomial(1, 0.8, (1500,))
f = lambda y: np.random.normal(1, 1, (64,)) if y else np.random.normal(0, 1, (64,))
x0 = [f(y) for y in y0]
x1 = [f(y) for y in y1]
#y0 = tf.one_hot(y0, 2)
#y1 = tf.one_hot(y1, 2)
x0 = tf.cast(x0, dtype= tf.float32)
x1 = tf.cast(x1, dtype= tf.float32)
dataDict = {0: {'x': x0, 'y': y0}, 1: {'x': x1, 'y': y1}}
prob = inv(x0)
cross_entropy_loss(y0, prob)
# Out:
# <tf.Tensor: id=147, shape=(), dtype=float32, numpy=0.6930306>

# %%
batch_size = 150
num_steps = 100
for key in dataDict:
    dictHand = dataDict[key]
    batch = tf.data.Dataset.from_tensor_slices((dictHand['x'], dictHand['y']))
    batch = batch.repeat().shuffle(5000).batch(batch_size).prefetch(1)
    dictHand['batch'] = batch.take(num_steps)
    
learningRate = 0.01
optimizer = tf.optimizers.Adam(learningRate)

# %%
with tf.GradientTape() as g:
    trainDataDict = dataDict
    modifiedDict = makeModifiedDict(trainDataDict)
    loss = 0
    for env in trainDataDict:
        dictHand = trainDataDict[env]
        logits = inv(dictHand['x'])
        loss += cross_entropy_loss(dictHand['y'], logits)
trainable_vars = inv.trainable_variables
gradients = g.gradient(loss, trainable_vars)

# %%
gradients
# Out:
# [<tf.Tensor: id=497, shape=(64, 32), dtype=float32, numpy=
#  array([[-6.34294847e-05, -3.52235656e-05,  2.50082830e-05, ...,
#           2.23196585e-05, -1.24630915e-05,  7.80650589e-06],
#         [-6.20641076e-05, -3.42296444e-05,  2.46874170e-05, ...,
#           2.20745314e-05, -1.23466416e-05,  7.63064600e-06],
#         [-6.51286755e-05, -3.61549028e-05,  2.47510397e-05, ...,
#           2.26524680e-05, -1.25610277e-05,  7.86674264e-06],
#         ...,
#         [-6.03035696e-05, -3.26044756e-05,  2.31246668e-05, ...,
#           2.10408816e-05, -1.17201807e-05,  7.33993738e-06],
#         [-6.28263151e-05, -3.47115747e-05,  2.46733907e-05, ...,
#           2.22478375e-05, -1.21929897e-05,  7.56841564e-06],
#         [-6.13393349e-05, -3.44834698e-05,  2.37022705e-05, ...,
#           2.17194738e-05, -1.18970020e-05,  7.47948434e-06]], dtype=float32)>,
#  <tf.Tensor: id=498, shape=(32, 16), dtype=float32, numpy=
#  array([[ 5.59406471e-04, -1.46849809e-04,  7.16585433e-04,
#          -5.32596459e-05,  1.35361683e-04, -7.71923951e-05,
#          -3.26284266e-04,  5.02511044e-04, -3.71767164e-05,
#           2.68636708e-04, -2.98644241e-04,  4.33975219e-04,
#           7.89776386e-05, -3.70121910e-04, -7.03437181e-05,
#          -3.40775841e-05],
#         [-7.23717676e-06,  1.81258292e-06, -1.08989479e-05,
#           8.28570592e-07, -2.13260864e-06,  1.00965553e-06,
#           4.49991785e-06, -6.24291715e-06,  4.04921593e-07,
#         [ 5.01710922e-04, -1.31718029e-04,  6.42469735e-04,
#          -4.77502872e-05,  1.21341502e-04, -6.92293761e-05,
#          -2.92576122e-04,  4.50697407e-04, -3.33556745e-05,
#           2.40938389e-04, -2.67867494e-04,  3.89186345e-04,
#           7.08599182e-05, -3.31920863e-04, -6.30951035e-05,
#          -3.05680151e-05],
#         [ 5.06554206e-04, -1.32966146e-04,  6.48688001e-04,
#          -4.82063842e-05,  1.22520622e-04, -6.98918520e-05,
#          -2.95380974e-04,  4.55001369e-04, -3.36718658e-05,
#           2.43238464e-04, -2.70389981e-04,  3.92915157e-04,
#           7.15226925e-05, -3.35119606e-04, -6.36977857e-05,
#          -3.08593008e-05],
#         [ 4.46107006e-04, -1.17124699e-04,  5.71101264e-04,
#          -4.24516038e-05,  1.07861400e-04, -6.15560566e-05,
#          -2.60151253e-04,  4.00799443e-04, -2.96638555e-05,
#           2.14242013e-04, -2.38155451e-04,  3.46074026e-04,
#           6.30071227e-05, -2.95025297e-04, -5.61093766e-05,
#          -2.71822937e-05],
#         [ 1.13480157e-04, -2.98646883e-05,  1.43999700e-04,
#          -1.06972939e-05,  2.71660865e-05, -1.56528513e-05,
#          -6.59558718e-05,  1.02182203e-04, -7.60258627e-06,
#           5.45534385e-05, -6.06031535e-05,  8.80455918e-05,
#           1.61667758e-05, -7.47339800e-05, -1.43132474e-05,
#          -6.93967559e-06],
#         [ 2.02947354e-04, -5.33275379e-05,  2.58999877e-04,
#          -1.92453062e-05,  4.88755140e-05, -2.79968481e-05,
#          -1.18194403e-04,  1.82435033e-04, -1.35342989e-05,
#           9.74909490e-05, -1.08373715e-04,  1.57426592e-04,
#           2.87552139e-05, -1.33973706e-04, -2.55498144e-05,
#          -1.23827867e-05]], dtype=float32)>,
#  <tf.Tensor: id=499, shape=(16, 6), dtype=float32, numpy=
#  array([[ 0.00298548, -0.01031508, -0.00372145,  0.00192036,  0.00856491,
#          -0.00691484],
#         [ 0.00321366, -0.01110346, -0.00400587,  0.00206715,  0.00921958,
#          -0.00744337],
#         [ 0.0034415 , -0.01189057, -0.00428982,  0.00221375,  0.00987334,
#          -0.00797112],
#         [ 0.00284579, -0.00983248, -0.00354733,  0.00183051,  0.00816417,
#          -0.00659131],
#         [ 0.00353914, -0.01222797, -0.00441155,  0.00227655,  0.01015345,
#          -0.00819728],
#         [ 0.00309332, -0.01068765, -0.00385585,  0.00198975,  0.00887436,
#          -0.00716464],
#         [ 0.00284849, -0.00984177, -0.00355068,  0.00183225,  0.00817192,
#          -0.00659756],
#         [ 0.00331634, -0.0114582 , -0.00413385,  0.0021332 ,  0.00951417,
#          -0.00768119],
#         [ 0.00294074, -0.01016049, -0.00366566,  0.0018916 ,  0.00843663,
#          -0.00681125],
#         [ 0.00312425, -0.01079455, -0.00389441,  0.00200964,  0.00896308,
#          -0.00723629],
#         [ 0.00338892, -0.01170896, -0.00422431,  0.00217989,  0.0097224 ,
#          -0.0078493 ],
#         [ 0.00323494, -0.01117692, -0.00403235,  0.00208086,  0.00928069,
#          -0.00749267],
#         [ 0.00278759, -0.0096313 , -0.00347474,  0.0017931 ,  0.00799729,
#          -0.00645653],
#         [ 0.00274573, -0.00948672, -0.00342259,  0.00176615,  0.00787712,
#          -0.00635955],
#         [ 0.00305619, -0.01055937, -0.00380957,  0.00196586,  0.00876781,
#          -0.00707864],
#         [ 0.00327411, -0.01131231, -0.00408121,  0.00210604,  0.00939302,
#          -0.00758338]], dtype=float32)>,
#  <tf.Tensor: id=500, shape=(6, 1), dtype=float32, numpy=
#  array([[-0.26198265],
#         [-0.25040138],
#         [-0.26065344],
#         [-0.22208485],
#         [-0.26565808],
#         [-0.22431362]], dtype=float32)>,
#  <tf.Tensor: id=501, shape=(32,), dtype=float32, numpy=
#  array([-2.32288057e-05, -9.78135995e-06,  9.11621009e-06, -1.90508999e-05,
#         -2.86205977e-05, -6.97605310e-06,  6.97069390e-06, -2.06265531e-06,
#         -6.50598122e-06,  1.38309060e-05, -3.99197552e-06,  4.78947959e-06,
#          1.49009265e-05,  2.34302843e-05, -6.46960962e-06, -5.02528110e-07,
#          7.98358906e-06, -4.21753211e-05,  1.27096530e-06,  2.81786743e-05,
#          3.04608602e-06,  2.46285035e-05,  2.03938253e-05,  8.81165124e-06,
#         -5.88864123e-06,  6.53579900e-06,  3.17009071e-05,  1.44261767e-05,
#          3.49979600e-05,  8.62735578e-06, -4.40401436e-06,  2.88004935e-06],
#        dtype=float32)>,
#  <tf.Tensor: id=502, shape=(16,), dtype=float32, numpy=
#  array([ 6.9955003e-04, -1.8370038e-04,  8.9485897e-04, -6.6500048e-05,
#          1.6898455e-04, -9.6520678e-05, -4.0780150e-04,  6.2857737e-04,
#         -4.6547895e-05,  3.3597639e-04, -3.7348157e-04,  5.4267078e-04,
#          9.8897544e-05, -4.6253204e-04, -8.8002897e-05, -4.2638829e-05],
#        dtype=float32)>,
#  <tf.Tensor: id=503, shape=(6,), dtype=float32, numpy=
#  array([ 0.00623272, -0.02153452, -0.00776913,  0.00400913,  0.0178809 ,
#         -0.01443602], dtype=float32)>,
#  <tf.Tensor: id=504, shape=(1,), dtype=float32, numpy=array([-0.49294773], dtype=float32)>,
#  None]

# %%
optimizer.apply_gradients(zip(gradients, trainable_vars))
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss.
# <tf.Variable 'UnreadVariable' shape=() dtype=int64, numpy=1>

# %%
logits
# Out:
# <tf.Tensor: id=353, shape=(1500, 2), dtype=float32, numpy=
# array([[0.46791384, 0.53208613],
#        [0.46787807, 0.5321219 ],
#        [0.46786284, 0.5321372 ],
#        ...,
#        [0.4677812 , 0.5322188 ],
#        [0.46773243, 0.5322676 ],
#        [0.4678466 , 0.5321534 ]], dtype=float32)>

# %%
logits = inv(trainDataDict[0]['x'])

# %%
y = trainDataDict[0]['y']
y = tf.one_hot(y, 2)
z = -y*tf.math.log(logits)

# %%
2*tf.reduce_mean(z)
# Out:
# <tf.Tensor: id=973, shape=(), dtype=float32, numpy=0.6947283>
